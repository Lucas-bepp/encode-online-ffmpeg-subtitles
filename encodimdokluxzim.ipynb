# %% [markdown]
# Colab de Encode de Legendas by Klux![Untitled568_20201112233450.png](data:image/png;base64,...)

# %% [markdown]
# Dê acesso ao drive com sua RAW para o encode!

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Importe sua fonte e sua legenda caso tenha feito um type e precise de fontes específicas.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-132185a2-459e-4fe5-ae1c-dc1a6cb303a1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-132185a2-459e-4fe5-ae1c-dc1a6cb303a1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving hello honey.otf to hello honey.otf

# %% [markdown]
# Mova sua fonte para a pasta padrão de fontes do Google Colab. (Apenas altere o nome da font no "/content/nome da fonte.otf" e lembre-se é só apenas a fonte não a legenda)

# %%
# !mv "/content/hello honey.otf" /usr/share/fonts/truetype/

# %% [markdown]
# E vamos para o encode, o ffmpeg já está instalado na maquina virtual se você precisar adaptar ele é só mudar no comando abaixo lembre-se que a RAW precisa estar no seu drive e você também precisa autorizar seu drive!

# %%
# !ffmpeg -i "caminho de sua raw" -movflags +faststart -map_metadata -1 "ass=caminho de sua legenda.ass",scale=1920:1080 -c:v libx264 -profile:v main -level:v 3.1 -preset ultrafast -crf 32 -c:a aac -b:a 128k nomedoarquivofinal.mp4
